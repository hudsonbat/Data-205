# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,5)

# %%
import json
import requests
import subprocess
import glob

# %%
process_chunksize = 10000
os.chdir('/Users/hudsonfinchbatista/Desktop/Python Datasets/Capstone')

mainCSV1 = 'CrimeChunk1.csv'
mainCSV2 = 'CrimeChunk2.csv'
mainCSV3 = 'CrimeChunk3.csv'
mainCSV4 = 'CrimeChunk4.csv'
mainCSV5 = 'CrimeChunk5.csv'
mainCSV6 = 'CrimeChunk6.csv'
mainCSV7 = 'CrimeChunk7.csv'
mainCSV8 = 'CrimeChunk8.csv'
mainCSV9 = 'CrimeChunk9.csv'
mainCSV10 = 'CrimeChunk10.csv'
mainCSV11 = 'CrimeChunk11.csv'
mainCSV12 = 'CrimeChunk12.csv'

mainDF1 = pd.read_csv(mainCSV1, chunksize=process_chunksize)
mainDF2 = pd.read_csv(mainCSV2, chunksize=process_chunksize)
mainDF3 = pd.read_csv(mainCSV3, chunksize=process_chunksize)
mainDF4 = pd.read_csv(mainCSV4, chunksize=process_chunksize)
mainDF5 = pd.read_csv(mainCSV5, chunksize=process_chunksize)
mainDF6 = pd.read_csv(mainCSV6, chunksize=process_chunksize)
mainDF7 = pd.read_csv(mainCSV7, chunksize=process_chunksize)
mainDF8 = pd.read_csv(mainCSV8, chunksize=process_chunksize)
mainDF9 = pd.read_csv(mainCSV9, chunksize=process_chunksize)
mainDF10 = pd.read_csv(mainCSV10, chunksize=process_chunksize)
mainDF11 = pd.read_csv(mainCSV11, chunksize=process_chunksize)
mainDF12 = pd.read_csv(mainCSV12, chunksize=process_chunksize)

# %%
census_api_url='https://api.census.gov/data/2019/acs/acs5?INSERT_KEY_HERE&get=NAME,B01001_001E,B01002_001E,B19013_001E,B08301_001E,B08301_010E,B15003_001E,B15003_017E,B15003_022E,B23025_003E,B23025_005E,B01001_002E,B01001_026E,B02001_002E,B02001_003E,B02001_004E,B02001_005E,B02001_007E&for=block%20group:*&in=state:24&in=county:031&in=tract:*'
    
responseCensus = requests.get(census_api_url, headers={'Content-Type': 'application/json'})
textCensus=json.loads(responseCensus.content)
tractDF = pd.DataFrame(textCensus)
print('Shape of census tract file: ' + str(tractDF.shape))

tractDF.rename(columns = tractDF.iloc[0], inplace=True)
tractDF = tractDF.iloc[1:]
tractDF.rename(index=str,columns={'B01001_001E':'Pop','B19013_001E':'Income',
                                  'B08301_001E':'Means of Transportation',
                                  'B08301_010E':'Public Transportation',
                                  'B15003_001E':'Educational Attainment','B15003_017E':'High School',
                                  'B15003_022E':'Bachelors',
                                  'B01002_001E':'Age','B23025_003E':'Total Laborforce',
                                  'B23025_005E':'Total Unemployed',
                                  'B01001_002E':'Male',
                                  'B01001_026E':'Female',
                                  'B02001_002E':'White',
                                  'B02001_003E':'Black',
                                  'B02001_004E':'American Indian',
                                  'B02001_005E':'Asian',
                                  'B02001_007E':'Other Race',
                                  'block group':'Block',
                                  'tract':'Tract'}, inplace=True)
# Out:
# Shape of census tract file: (615, 22)

# %%
tract2 = tractDF.sort_values(by='Tract')
tract2.head()
# Out:
#                                                   NAME   Pop   Age  Income  \
# 97   Block Group 1, Census Tract 7001.01, Montgomer...  1922  46.6  156250
# 158  Block Group 3, Census Tract 7001.01, Montgomer...   800  47.9  135313
# 159  Block Group 2, Census Tract 7001.01, Montgomer...  1931  48.7  222619
# 494  Block Group 3, Census Tract 7001.03, Montgomer...  3112  48.1  172986
# 176  Block Group 2, Census Tract 7001.03, Montgomer...  1017  50.4  218173
#
#     Means of Transportation Public Transportation Educational Attainment  \
# 97                     1030                    51                   1314
# 158                     424                     3                    573
# 159                     942                    62                   1326
# 494                    1733                   169                   2258
# 176                     722                    12                    715
#
#     High School Bachelors Total Laborforce  ... Female White Black  \
# 97          110       355             1067  ...    912  1463   184
# 158          45       159              466  ...    425   727    10
# 159         213       416             1105  ...   1052  1363    39
# 494         216       783             1768  ...   1549  1886   345
# 176          60       309              727  ...    463   647   193
#
#     American Indian Asian Other Race state county   Tract Block
# 97                0   160         13    24    031  700101     1
# 158               0    61          0    24    031  700101     3
# 159               0   183        214    24    031  700101     2
# 494               0   620        136    24    031  700103     3
# 176               0    98          4    24    031  700103     2
#
# [5 rows x 22 columns]

# %%
tractDF['Block'] = tractDF['Block'].apply(str)
tractDF['Tract'] = tractDF['Tract'].apply(str)

for i in range(0,len(tractDF)):
    tractDF['Block'][i] = tractDF['Tract'][i] + tractDF['Block'][i]
    
tractDF.head()
# Out:
#                                                 NAME   Pop   Age  Income  \
# 1  Block Group 4, Census Tract 7032.08, Montgomer...  1646  37.2  149375
# 2  Block Group 4, Census Tract 7015.09, Montgomer...  3041  33.1   41104
# 3  Block Group 2, Census Tract 7015.08, Montgomer...   590  31.3   62448
# 4  Block Group 1, Census Tract 7039.01, Montgomer...  1553  42.0  139318
# 5  Block Group 2, Census Tract 7057.02, Montgomer...  1697  58.5  144688
#
#   Means of Transportation Public Transportation Educational Attainment  \
# 1                     822                    92                   1122
# 2                    1196                   293                   1778
# 3                     286                    17                    374
# 4                     928                   157                   1049
# 5                     719                    43                   1329
#
#   High School Bachelors Total Laborforce  ... Female White Black  \
# 1          88       292              858  ...    829   941   319
# 2         412       242             1610  ...   1827   572  1284
# 3           9        67              333  ...    285   149   263
# 4          97       381              977  ...    805   743   354
# 5          43       354              749  ...    886  1602    21
#
#   American Indian Asian Other Race state county   Tract    Block
# 1               0    16        340    24    031  703208  7032084
# 2              14   167        888    24    031  701509  7015094
# 3               0    67         26    24    031  701508  7015082
# 4               0   295        123    24    031  703901  7039011
# 5               0    41          8    24    031  705702  7057022
#
# [5 rows x 22 columns]

# %%
tractDF.set_index('Block', inplace=True)
tractDF.drop(['NAME', 'state', 'county','Tract'],inplace=True, axis=1)
tractDF=tractDF[['Pop','Income','Means of Transportation','Public Transportation','Educational Attainment','High School','Bachelors','Total Laborforce','Total Unemployed','Age','Male','Female','White','Black','American Indian','Asian','Other Race']].apply(pd.to_numeric, errors='coerce')
print(tractDF.info())
print(tractDF.head(8))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, 7032084 to 7013061
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Pop                      614 non-null    int64
#  1   Income                   614 non-null    int64
#  2   Means of Transportation  614 non-null    int64
#  3   Public Transportation    614 non-null    int64
#  4   Educational Attainment   614 non-null    int64
#  5   High School              614 non-null    int64
#  6   Bachelors                614 non-null    int64
#  7   Total Laborforce         614 non-null    int64
#  8   Total Unemployed         614 non-null    int64
#  9   Age                      614 non-null    float64
#  10  Male                     614 non-null    int64
#  11  Female                   614 non-null    int64
#  12  White                    614 non-null    int64
#  13  Black                    614 non-null    int64
#  14  American Indian          614 non-null    int64
#  15  Asian                    614 non-null    int64
#  16  Other Race               614 non-null    int64
# dtypes: float64(1), int64(16)
# memory usage: 86.3+ KB
# None
#           Pop  Income  Means of Transportation  Public Transportation  \
# Block
# 7032084  1646  149375                      822                     92
# 7015094  3041   41104                     1196                    293
# 7015082   590   62448                      286                     17
# 7039011  1553  139318                      928                    157
# 7057022  1697  144688                      719                     43
# 7058003  1141  231250                      589                     27
# 7059032  1331  250001                      693                     34
# 7014143  2336   77457                     1222                    176
#
#          Educational Attainment  High School  Bachelors  Total Laborforce  \
# Block
# 7032084                    1122           88        292               858
# 7015094                    1778          412        242              1610
# 7015082                     374            9         67               333
# 7039011                    1049           97        381               977
# 7057022                    1329           43        354               749
# 7058003                     789           49        213               579
# 7059032                    1028           42        285               706
# 7014143                    1455          299        276              1358
#
#          Total Unemployed   Age  Male  Female  White  Black  American Indian  \
# Block
# 7032084                44  37.2   817     829    941    319                0
# 7015094               354  33.1  1214    1827    572   1284               14
# 7015082                 9  31.3   305     285    149    263                0
# 7039011                32  42.0   748     805    743    354                0
# 7057022                30  58.5   811     886   1602     21                0
# 7058003                 3  44.7   584     557   1077     31                0
# 7059032                13  52.6   552     779    841     56                0
# 7014143                63  40.2   979    1357    645   1124                0
#
#          Asian  Other Race
# Block
# 7032084     16         340
# 7015094    167         888
# 7015082     67          26
# 7039011    295         123
# 7057022     41           8
# 7058003      1           8
# 7059032    365          26
# 7014143    383         103

# %%
#Define tract finding function
def getBlock(lonlat):
    block = -999
    api_url='https://geo.fcc.gov/api/census/area?lat='+str(lonlat[0])+'&lon='+str(lonlat[1])+'&format=json'
    headers = {'Content-Type': 'application/json'}
    response = requests.get(api_url, headers=headers)
    try:
        block=json.loads(response.content.decode('utf-8'))['results'][0]['block_fips'][5:12]
    except:
        print('No Block found from FCC geo API')
    return block

# %%
    df1 = pd.DataFrame()
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF1:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
            print(df_group.head(5))
    
            df1 = df1.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
#    Unnamed: 0  Incident ID  Offence Code  CR Number    Dispatch Date / Time  \
# 0         742    201284536          1399  200015419  04/08/2020 03:24:11 PM
# 1         863    201283685          2610  200014367  03/29/2020 07:32:27 AM
# 2        1507    201260657          3562  190049016                     NaN
# 3        1850    201281812          2501  200012514  03/13/2020 11:51:37 PM
# 4        1929    201259611          2304  190047828  10/05/2019 01:36:00 PM
#
#   NIBRS Code  Victims             Crime Name1  \
# 0        13B        2    Crime Against Person
# 1        26F        1  Crime Against Property
# 2        35A        1   Crime Against Society
# 3        250        1  Crime Against Property
# 4        23G        1  Crime Against Property
#
#                                    Crime Name2                  Crime Name3  \
# 0                               Simple Assault         ASSAULT - 2ND DEGREE
# 1                               Identity Theft               IDENTITY THEFT
# 2                     Drug/Narcotic Violations  DRUGS - MARIJUANA - POSSESS
# 3                       Counterfeiting/Forgery            FORGERY OF CHECKS
# 4  Theft of Motor Vehicle Parts or Accessories         LARCENY - AUTO PARTS
#
#    ... Total Laborforce Total Unemployed Age Male  Female White Black  \
# 0  ...              NaN              NaN NaN  NaN     NaN   NaN   NaN
# 1  ...              NaN              NaN NaN  NaN     NaN   NaN   NaN
# 2  ...              NaN              NaN NaN  NaN     NaN   NaN   NaN
# 3  ...              NaN              NaN NaN  NaN     NaN   NaN   NaN
# 4  ...              NaN              NaN NaN  NaN     NaN   NaN   NaN
#
#   American Indian Asian  Other Race
# 0             NaN   NaN         NaN
# 1             NaN   NaN         NaN
# 2             NaN   NaN         NaN
# 3             NaN   NaN         NaN
# 4             NaN   NaN         NaN
#
# [5 rows x 49 columns]
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
#    Unnamed: 0  Incident ID  Offence Code  CR Number    Dispatch Date / Time  \
# 0       10011    201091844          3561   16038203                     NaN
# 1       11439    201276474          2305  200005846  02/04/2020 06:13:05 PM
# 2       11828    201307912          5404  200043097  11/01/2020 02:21:52 PM
# 3       11947    201294112          9201  200026672  07/09/2020 03:31:48 PM
# 4       12907    201261604          5311  190050255  10/19/2019 08:42:28 PM
#
#   NIBRS Code  Victims             Crime Name1                  Crime Name2  \
# 0        35A        1   Crime Against Society     Drug/Narcotic Violations
# 1        23F        1  Crime Against Property     Theft From Motor Vehicle
# 2        90D        1   Crime Against Society  Driving Under the Influence
# 3        90Z        1                   Other           All Other Offenses
# 4        90C        1   Crime Against Society           Disorderly Conduct
#
#                           Crime Name3  ... Total Laborforce Total Unemployed  \
# 0         DRUGS - MARIJUANA - SMUGGLE  ...              NaN              NaN
# 1                 LARCENY - FROM AUTO  ...              NaN              NaN
# 2  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 3                            OVERDOSE  ...              NaN              NaN
# 4   PUBLIC PEACE - DISORDERLY CONDUCT  ...              NaN              NaN
#
#   Age Male  Female White Black American Indian Asian  Other Race
# 0 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 1 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 2 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 3 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 4 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
#
# [5 rows x 49 columns]

# %%
len(df1)
# Out:
# 20000

# %%
df1.to_csv('MC_NewCrime1.csv')

# %%
df2 = pd.DataFrame();df3 = pd.DataFrame();df4 = pd.DataFrame();df5 = pd.DataFrame();
df6 = pd.DataFrame();df7 = pd.DataFrame();df8 = pd.DataFrame();df9 = pd.DataFrame();
df10 = pd.DataFrame();df11 = pd.DataFrame();df12 = pd.DataFrame()

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF2:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df2 = df2.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df2)
# Out:
# 20000

# %%
df2.to_csv('MC_NewCrime2.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF4:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
            print(df_group.head(5))
    
            df4 = df4.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
#    Unnamed: 0  Incident ID  Offence Code  CR Number    Dispatch Date / Time  \
# 0       61466    201124422          3562   17012309                     NaN
# 1       63890    201126886          5404   17015387                     NaN
# 2       63993    201127116          2305   17015557                     NaN
# 3       63994    201127116          9099   17015557                     NaN
# 4       64730    201128661          5404  170500456  04/05/2017 01:35:39 AM
#
#   NIBRS Code  Victims             Crime Name1                  Crime Name2  \
# 0        35A        1   Crime Against Society     Drug/Narcotic Violations
# 1        90D        1   Crime Against Society  Driving Under the Influence
# 2        23F        1  Crime Against Property     Theft From Motor Vehicle
# 3        90Z        1   Crime Against Society           All Other Offenses
# 4        90D        1   Crime Against Society  Driving Under the Influence
#
#                           Crime Name3  ... Total Laborforce Total Unemployed  \
# 0         DRUGS - MARIJUANA - POSSESS  ...              NaN              NaN
# 1  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 2                 LARCENY - FROM AUTO  ...              NaN              NaN
# 3                  ALL OTHER OFFENSES  ...              NaN              NaN
# 4  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
#
#   Age Male  Female White Black American Indian Asian  Other Race
# 0 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 1 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 2 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 3 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 4 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
#
# [5 rows x 49 columns]
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
#    Unnamed: 0  Incident ID  Offence Code  CR Number    Dispatch Date / Time  \
# 0       70280    201149138          5404  170525620  08/18/2017 10:50:58 PM
# 1       70543    201149911          5404  170526934  08/26/2017 12:17:18 AM
# 2       71251    201152241          4199  170529265  09/07/2017 07:45:54 PM
# 3       71406    201152727          3562  170529932  09/11/2017 03:20:52 PM
# 4       71428    201152792          3562  170530656  09/14/2017 10:35:38 PM
#
#   NIBRS Code  Victims            Crime Name1                  Crime Name2  \
# 0        90D        1  Crime Against Society  Driving Under the Influence
# 1        90D        1  Crime Against Society  Driving Under the Influence
# 2        90G        1  Crime Against Society        Liquor Law Violations
# 3        35A        1  Crime Against Society     Drug/Narcotic Violations
# 4        35A        1  Crime Against Society     Drug/Narcotic Violations
#
#                           Crime Name3  ... Total Laborforce Total Unemployed  \
# 0  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 1  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 2           LIQUOR (DESCRIBE OFFENSE)  ...              NaN              NaN
# 3         DRUGS - MARIJUANA - POSSESS  ...              NaN              NaN
# 4         DRUGS - MARIJUANA - POSSESS  ...              NaN              NaN
#
#   Age Male  Female White Black American Indian Asian  Other Race
# 0 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 1 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 2 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 3 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 4 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
#
# [5 rows x 49 columns]

# %%
len(df4)
# Out:
# 20000

# %%
df4.to_csv('MC_NewCrime4.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF5:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df5 = df5.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df5)
# Out:
# 20000

# %%
df5.to_csv('MC_NewCrime5.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF6:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df6 = df6.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df6)
# Out:
# 20000

# %%
df6.to_csv('MC_NewCrime6.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF7:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df7 = df7.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df7)
# Out:
# 20000

# %%
df7.to_csv('MC_NewCrime7.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF8:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df8 = df8.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df8)
# Out:
# 20000

# %%
df8.to_csv('MC_NewCrime8.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF9:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df9 = df9.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df9)
# Out:
# 20000

# %%
df9.to_csv('MC_NewCrime9.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF10:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df10 = df10.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df10)
# Out:
# 20000

# %%
df10.to_csv('MC_NewCrime10.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF11:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df11 = df11.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df11)
# Out:
# 20000

# %%
df11.to_csv('MC_NewCrime11.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF12:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
    
            df12 = df12.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(7000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API

# %%
len(df12)
# Out:
# 17000

# %%
df12.to_csv('MC_NewCrime12.csv')

# %%
    itld=0
    itlu=1
    
    for mainDF_chunk in mainDF3:
            nLinesMainCSVd=itld*process_chunksize
            nLinesMainCSVu=itlu*process_chunksize
            print('New group from main DF, lines '+str(nLinesMainCSVd) + ' to ' + str(nLinesMainCSVu) )

            # Cleaning main
            mainDF_chunk.dropna(subset=['Location'],inplace=True)
            mainDF_chunk['Location']=mainDF_chunk['Location'].map(lambda x: eval(str(x)))
            mainDF_chunk[['Start_Date_Time','End_Date_Time']].apply(pd.to_datetime,errors='coerce')
            print('Dimension of main DF group:' + str(mainDF_chunk.shape))
    
            # Add Tract from FCC geo
            mainDF_chunk['Block']=mainDF_chunk.Location.map(lambda x: getBlock(x))
    
            df_group = pd.merge(mainDF_chunk,tractDF, how='left', on='Block', sort=True)
            print(df_group.head(5))
    
            df3 = df3.append(df_group,sort=True)
    
            itlu+=1
            itld+=1
# Out:
# New group from main DF, lines 0 to 10000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
#    Unnamed: 0  Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0       40536    201272175         2303  200000418  01/03/2020 01:27:20 PM
# 1       40603    201108686         5404   16059547                     NaN
# 2       40661    201108716         5404   16060195                     NaN
# 3       41255    201109146         5404   16060688                     NaN
# 4       41285    201109159         9199   16060674                     NaN
#
#   NIBRS Code  Victims             Crime Name1                  Crime Name2  \
# 0        23C        1  Crime Against Property                  Shoplifting
# 1        90D        1   Crime Against Society  Driving Under the Influence
# 2        90D        1   Crime Against Society  Driving Under the Influence
# 3        90D        1   Crime Against Society  Driving Under the Influence
# 4        90Z        1                   Other           All Other Offenses
#
#                           Crime Name3  ... Total Laborforce Total Unemployed  \
# 0               LARCENY - SHOPLIFTING  ...              NaN              NaN
# 1  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 2  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 3  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 4                  POLICE INFORMATION  ...              NaN              NaN
#
#   Age Male  Female White Black American Indian Asian  Other Race
# 0 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 1 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 2 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 3 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 4 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
#
# [5 rows x 49 columns]
# New group from main DF, lines 10000 to 20000
# Dimension of main DF group:(10000, 31)
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
# No Block found from FCC geo API
#    Unnamed: 0  Incident ID  Offence Code  CR Number    Dispatch Date / Time  \
# 0       50656    201277949          5404  200007778  02/16/2020 04:10:42 AM
# 1       51202    201115451          5404   17001252                     NaN
# 2       52008    201116106          3512   17001948                     NaN
# 3       52411    201116497          5404   17002545                     NaN
# 4       52999    201117020          2902   17002860                     NaN
#
#   NIBRS Code  Victims             Crime Name1  \
# 0        90D        1   Crime Against Society
# 1        90D        1   Crime Against Society
# 2        35A        1   Crime Against Society
# 3        90D        1   Crime Against Society
# 4        290        1  Crime Against Property
#
#                                 Crime Name2  \
# 0               Driving Under the Influence
# 1               Driving Under the Influence
# 2                  Drug/Narcotic Violations
# 3               Driving Under the Influence
# 4  Destruction/Damage/Vandalism of Property
#
#                           Crime Name3  ... Total Laborforce Total Unemployed  \
# 0  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 1  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 2            DRUGS - HEROIN - POSSESS  ...              NaN              NaN
# 3  DRIVING UNDER THE INFLUENCE LIQUOR  ...              NaN              NaN
# 4           DAMAGE PROPERTY - PRIVATE  ...              NaN              NaN
#
#   Age Male  Female White Black American Indian Asian  Other Race
# 0 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 1 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 2 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 3 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
# 4 NaN  NaN     NaN   NaN   NaN             NaN   NaN         NaN
#
# [5 rows x 49 columns]

# %%
len(df3)
# Out:
# 20000

# %%
df3.to_csv('MC_NewCrime3.csv')
